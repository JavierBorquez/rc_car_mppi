# %%
import numpy as np
import matplotlib.pyplot as plt
from jax.scipy.interpolate import RegularGridInterpolator
import mat73
import time

import jax
import jax.numpy as jnp
from jax import random, jit
import matplotlib.pyplot as plt



# ------------------     MATLAB STUFF  ----------------------------------
def get_matlab_variables(mat_file_path):
    variables = mat73.loadmat(mat_file_path)
    #double gets converted to np array by default
    value_func_data = variables['Vx']
    lx_data = variables['lx'] 
    tau2 = variables['tau2']

    #Deriv is cell which gets converted into list of lists
    deriv_x_data = np.array(variables['Deriv'][0])
    deriv_x_data = deriv_x_data.squeeze()
    deriv_y_data = np.array(variables['Deriv'][1])
    deriv_y_data = deriv_y_data.squeeze()
    deriv_th_data = np.array(variables['Deriv'][2])
    deriv_th_data = deriv_th_data.squeeze()
    
    #uOpt is also cell which gets converted into list of lists
    uOpt_vel = np.array(variables['uOpt'][0])
    uOpt_vel = uOpt_vel.squeeze()
    uOpt_angle = np.array(variables['uOpt'][1])
    uOpt_angle = uOpt_angle.squeeze() 

    #g is struct whic gets converted into dic
    #vs is cell which give a list
    x_coord=np.array(variables['g']['vs'][0])
    y_coord=np.array(variables['g']['vs'][1])
    th_coord=np.array(variables['g']['vs'][2])
    x_coord = x_coord.squeeze()
    y_coord = y_coord.squeeze()
    th_coord = th_coord.squeeze()

    matlab_var_dict = dict( value_func_data=value_func_data,
                            lx_data=lx_data,
                            deriv_x_data=deriv_x_data,
                            deriv_y_data=deriv_y_data,
                            deriv_th_data=deriv_th_data,
                            uOpt_vel=uOpt_vel,
                            uOpt_angle=uOpt_angle,
                            x_coord=x_coord,
                            y_coord=y_coord,
                            th_coord=th_coord,
                            tau2=tau2
                           )
    return matlab_var_dict

# def get_value_function(matlab_var_dict):
#    val_func_eval = RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord']), matlab_var_dict['value_func_data'] ,  bounds_error=False, fill_value=None)
#    return val_func_eval

# def get_lx_function(matlab_var_dict):
#    lx_eval = RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord']), matlab_var_dict['lx_data'] ,  bounds_error=False, fill_value=None)
#    return lx_eval

# def get_deriv_x_function(matlab_var_dict):
#    deriv_x_eval = RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord'] ), matlab_var_dict['deriv_x_data'] ,  bounds_error=False, fill_value=None)
#    return deriv_x_eval

# def get_deriv_y_function(matlab_var_dict):
#    deriv_y_eval = RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord'] ), matlab_var_dict['deriv_y_data'] ,  bounds_error=False, fill_value=None)
#    return deriv_y_eval

# def get_deriv_th_function(matlab_var_dict):
#    deriv_th_eval = RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord'] ), matlab_var_dict['deriv_th_data'] ,  bounds_error=False, fill_value=None)
#    return deriv_th_eval

# def get_opt_control( deriv_x_fun, deriv_y_fun, deriv_th_fun, state, vMax, vMin, angleMax, u_mode = 'max'):
#     # if strcmp(uMode, 'max')
#     # uOpt{2} = (deriv{3}>=0)*obj.angleMax + (deriv{3}<0)*(-obj.angleMax);  %steering control
#     # det1 = deriv{1} .* cos(y{3}) + deriv{2} .* sin(y{3}) + deriv{3} .* tan(uOpt{2}).*(1/obj.L);
#     # uOpt{1} = (det1 >= 0) * max(obj.vRange) + (det1 < 0) * min(obj.vRange);%vel control
#     x_deriv = deriv_x_fun(state)
#     y_deriv = deriv_y_fun(state)
#     th_deriv = deriv_th_fun(state)
#     if u_mode == 'max':        
#         opt_angle = angleMax * ( th_deriv >= 0 ) + (-angleMax) * ( th_deriv < 0 )
#         det1 = x_deriv * np.cos(state[2]) + y_deriv * np.sin(state[2]) + th_deriv * np.tan(opt_angle)*(1/0.235) #0.235 is the wheelbase L
#         opt_v = vMax * ( det1 >= 0 ) + vMin * ( det1 < 0 )
#     else:
#         raise NotImplementedError
#     return opt_v, opt_angle
  
@jit
def get_opt_control( x_deriv, y_deriv, th_deriv, state, vMax, vMin, angleMax):
    # if strcmp(uMode, 'max')
    # uOpt{2} = (deriv{3}>=0)*obj.angleMax + (deriv{3}<0)*(-obj.angleMax);  %steering control
    # det1 = deriv{1} .* cos(y{3}) + deriv{2} .* sin(y{3}) + deriv{3} .* tan(uOpt{2}).*(1/obj.L);
    # uOpt{1} = (det1 >= 0) * max(obj.vRange) + (det1 < 0) * min(obj.vRange);%vel control

    opt_angle = angleMax * ( th_deriv >= 0 ) + (-angleMax) * ( th_deriv < 0 )
    det1 = x_deriv * jnp.cos(state[2]) + y_deriv * jnp.sin(state[2]) + th_deriv * jnp.tan(opt_angle)*(1/0.235) #0.235 is the wheelbase L
    opt_v = vMax * ( det1 >= 0 ) + vMin * ( det1 < 0 )

    return opt_v, opt_angle

#---------------------- Load MATLAB ---------------------------------------------------------
#v1 baseline brt
#v3 added uopt lookup table
matlab_var_dict= get_matlab_variables('/home/javier/jax_work/mppi/rc_car_mppi/brt_rc_wh_coarse_v3.mat')

data = matlab_var_dict['value_func_data']
data_lx = matlab_var_dict['lx_data']
uOpt_vel = matlab_var_dict['uOpt_vel']
uOpt_angle = matlab_var_dict['uOpt_angle']
coords = [matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord']]

data = jnp.array(data)
uOpt_vel = jnp.array(uOpt_vel)
uOpt_angle = jnp.array(uOpt_angle)
coords = [jnp.array(coord) for coord in coords]

#---------------------- Interpolators ---------------------------------------------------------
val_fun = jax.jit(RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord']), matlab_var_dict['value_func_data'] ,  bounds_error=False, fill_value=None))
lx_fun = jax.jit(RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord']), matlab_var_dict['lx_data'] ,  bounds_error=False, fill_value=None))
deriv_x_fun = jax.jit(RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord'] ), matlab_var_dict['deriv_x_data'] ,  bounds_error=False, fill_value=None))
deriv_y_fun = jax.jit(RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord'] ), matlab_var_dict['deriv_y_data'] ,  bounds_error=False, fill_value=None))
deriv_th_fun= jax.jit(RegularGridInterpolator(( matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], matlab_var_dict['th_coord'] ), matlab_var_dict['deriv_th_data'] ,  bounds_error=False, fill_value=None))

# %%
import sys
print(type(uOpt_vel))
print(data.shape)

# %%
# Experiment Constants
DT = 0.02
L = 0.235
V_MIN = 0.5
V_MAX = 1.5
DELTA_MIN = -0.5
DELTA_MAX = 0.5

@jit
def ackerman_dynamics(state, control, dt=DT, L=L):
    x, y, theta = state
    v, delta = control
    
    x_dot = v * jnp.cos(theta)
    y_dot = v * jnp.sin(theta)
    theta_dot = v * jnp.tan(delta) * (1 / L)
    
    new_x = x + x_dot * dt
    new_y = y + y_dot * dt
    new_theta = theta + theta_dot * dt
    
    # Handle the angle wrap around
    new_theta = ((new_theta + jnp.pi) % (2 * jnp.pi)) - jnp.pi
    
    return new_x, new_y, new_theta

@jit
def cost_function(states, controls, v_target=V_MAX, delta_target=0.0):
    x = states[0, :]
    v = controls[:, 0]
    delta = controls[:, 1]
    cost = jnp.sum((v - v_target) ** 2)
    cost += jnp.sum((delta - delta_target) ** 2) * 5.0
    return cost 

@jit
def simulate_ackerman(initial_state, disturbed_controls, data, uOpt_vel, uOpt_angle, coords, dt=DT, L=L):
    def step(state, control):
        #find index in coords closest to state
        # x_idx = jnp.argmin(jnp.abs(coords[0] - state[0]))
        # y_idx = jnp.argmin(jnp.abs(coords[1] - state[1]))
        # th_idx = jnp.argmin(jnp.abs(coords[2] - state[2]))        
        # value_now = data[x_idx, y_idx, th_idx]
        # uOpt_vel_now = uOpt_vel[x_idx, y_idx, th_idx]
        # uOpt_angle_now = uOpt_angle[x_idx, y_idx, th_idx]
        
        value_now = val_fun(state_now)
        x_deriv_now = deriv_x_fun(state_now)
        y_deriv_now = deriv_y_fun(state_now)
        th_deriv_now = deriv_th_fun(state_now)
        uOpt= jnp.array(get_opt_control(x_deriv_now, y_deriv_now, th_deriv_now, state_now, V_MAX, V_MIN, DELTA_MAX))
        
        # Update control with optimal values
        control = uOpt*(value_now<0.1) + control*(value_now>=0.1)
        new_state = ackerman_dynamics(state, control.squeeze(), dt, L)
        return new_state, new_state
    
    # Use jax.lax.scan to iterate over the controls and accumulate the states
    _, states = jax.lax.scan(step, initial_state, disturbed_controls)
    
    # Convert states to a JAX array
    states = jnp.array(states)
    
    # Compute the cost for the entire array of states and controls
    total_cost = cost_function(states, disturbed_controls)
    
    return states, total_cost

# Vectorize the simulation function to run multiple trajectories in parallel
simulate_ackerman_parallel = jax.vmap(simulate_ackerman, in_axes=(None, 0, None, None, None, None))

# ------------------     SIMULATION INIT  ----------------------------------

# Example usage with jax.random
key = random.PRNGKey(0)

# Simulation parameters
HALLUCINATION_STEPS = 100
NUM_THREADS = 500
TEMPERATURE = 1.0
EXPERIMENT_T = 12.0
EXPERIMENT_STEPS = int(EXPERIMENT_T / DT)
INITIAL_STATE = (3.0, 0.5, 0.0)

# Safety filter parameters
FILTER_EXPERIMENT = True
EXPERIMENT_THRESHOLD = 0.1
FILTER_HALLUCINATIONS = False

# Data structures
state_now = tuple(jnp.array([value]) for value in INITIAL_STATE)
state_history = []
control_history = []
hallucination_history = []
m_t = np.zeros((EXPERIMENT_STEPS, 3))

# timing structures
time_rollouts = []
time_sim_step = [] 

# Generate nominal control inputs
nominal_velocities = jnp.ones(HALLUCINATION_STEPS)
nominal_steering_angles = jnp.zeros(HALLUCINATION_STEPS)
nominal_controls = jnp.stack((nominal_velocities, nominal_steering_angles), axis=1)

# ------------------     SIMULATION LOOP  ----------------------------------

for i in range(EXPERIMENT_STEPS):
    start_time_sim_step = time.time()
    # Generate random noise for multiple trajectories
    control_noise = random.normal(key, shape=(NUM_THREADS, HALLUCINATION_STEPS, 2)) * jnp.array([0.2, 0.1])  # Adjust the scale of noise as needed

    # Combine controls and noise before passing to the simulation function, clip to valid range
    disturbed_controls = nominal_controls + control_noise
    disturbed_controls = jnp.clip(disturbed_controls, jnp.array([V_MIN, DELTA_MIN]), jnp.array([V_MAX, DELTA_MAX]))
    # Grab the noise that was actually applied
    control_noise = disturbed_controls - nominal_controls    

    # Perform the simulation
    start_time_rollouts = time.time()
    states_parallel, costs_parallel = simulate_ackerman_parallel(state_now, disturbed_controls, data, uOpt_vel, uOpt_angle, coords)
    end_time_rollouts = time.time()
    
    # Update nominal controls using the costs and noise
    weights = jnp.exp(-TEMPERATURE * (costs_parallel))
    weights = weights[:, jnp.newaxis, jnp.newaxis]  # Adjust shape for broadcasting
    nominal_controls = nominal_controls + jnp.sum(weights * control_noise, axis=0) / jnp.sum(weights)
    # Clip the controls to the valid range
    nominal_controls = jnp.clip(nominal_controls, jnp.array([V_MIN, DELTA_MIN]), jnp.array([V_MAX, DELTA_MAX]))
    
    # Check value function and apply LR filter
    value_now = val_fun(state_now)
    lx_now = lx_fun(state_now[0:2])
    x_deriv_now = deriv_x_fun(state_now)
    y_deriv_now = deriv_y_fun(state_now)
    th_deriv_now = deriv_th_fun(state_now)
    uOpt_vel_now, uOpt_angle_now = get_opt_control(x_deriv_now, y_deriv_now, th_deriv_now, state_now, V_MAX, V_MIN, DELTA_MAX)
  
    if FILTER_EXPERIMENT and value_now < EXPERIMENT_THRESHOLD:
        control_now = jnp.array([uOpt_vel_now,uOpt_angle_now])
        control_now = control_now.squeeze()
        m_t[i] = [0.8, 0.4, 0.4] 
    else:
        control_now = nominal_controls[0]
        m_t[i] = [0.4, 0.4, 0.8] 
        
    # Apply the first control from the updated nominal controls to the system and store the new state
    state_now = ackerman_dynamics(state_now, control_now)
    state_history.append(state_now)
    control_history.append(control_now)
    hallucination_history.append(states_parallel)
    
    # Move the control sequence one step forward and maintain the last control
    nominal_controls = jnp.roll(nominal_controls, -1, axis=0)
    nominal_controls = nominal_controls.at[-1].set(nominal_controls[-2])

    end_time_sim_step = time.time()
    # Print and save the elapsed times
    print(f"Elapsed time for rollouts {(end_time_rollouts - start_time_rollouts)*1000:.1f} ms")
    print(f"Elapsed time for sim step {(end_time_sim_step - start_time_sim_step)*1000:.1f} ms")
    time_rollouts.append((end_time_rollouts - start_time_rollouts)*1000)
    time_sim_step.append((end_time_sim_step - start_time_sim_step)*1000)
    

#remove first 5 timings
time_rollouts = time_rollouts[5:]
time_sim_step = time_sim_step[5:]
# timing statistics avg+-std
print(f"Average time for rollouts {np.mean(time_rollouts):.1f} ± {np.std(time_rollouts):.1f} ms")
print(f"Average time for sim step {np.mean(time_sim_step):.1f} ± {np.std(time_sim_step):.1f} ms")
# Out:
# <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>
# <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>
# <class 'tuple'>
# <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>
# <class 'jax._src.interpreters.partial_eval.DynamicJaxprTracer'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 121
#     119 # Perform the simulation
#     120 start_time_rollouts = time.time()
# --> 121 states_parallel, costs_parallel = simulate_ackerman_parallel(state_now, disturbed_controls, data, uOpt_vel, uOpt_angle, coords)
#     122 end_time_rollouts = time.time()
#     124 # Update nominal controls using the costs and noise
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/api.py:1240, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1237 in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1238 axis_size_ = (axis_size if axis_size is not None else
#    1239               _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1240 out_flat = batching.batch(
#    1241     flat_fun, axis_name, axis_size_, in_axes_flat,
#    1242     lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1243     spmd_axis_name=spmd_axis_name
#    1244 ).call_wrapped(*args_flat)
#    1245 return tree_unflatten(out_tree(), out_flat)
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/linear_util.py:188, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     185 gen = gen_static_args = out_store = None
#     187 try:
# --> 188   ans = self.f(*args, **dict(self.params, **kwargs))
#     189 except:
#     190   # Some transformations yield from inside context managers, so we have to
#     191   # interrupt them before reraising the exception. Otherwise they will only
#     192   # get garbage-collected at some later time, running their cleanup tasks
#     193   # only after this exception is handled, which can corrupt the global
#     194   # state.
#     195   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/pjit.py:250, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     248 @api_boundary
#     249 def cache_miss(*args, **kwargs):
# --> 250   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     251       fun, infer_params_fn, *args, **kwargs)
#     252   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     253   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/pjit.py:158, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     157 def _python_pjit_helper(fun, infer_params_fn, *args, **kwargs):
# --> 158   args_flat, _, params, in_tree, out_tree, _ = infer_params_fn(
#     159       *args, **kwargs)
#     160   for arg in args_flat:
#     161     dispatch.check_arg(arg)
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/api.py:306, in jit.<locals>.infer_params(*args, **kwargs)
#     299 def infer_params(*args, **kwargs):
#     300   pjit_info_args = pjit.PjitInfo(
#     301       fun=fun, in_shardings=in_shardings,
#     302       out_shardings=out_shardings, static_argnums=static_argnums,
#     303       static_argnames=static_argnames, donate_argnums=donate_argnums,
#     304       device=device, backend=backend, keep_unused=keep_unused,
#     305       inline=inline, resource_env=None, abstracted_axes=abstracted_axes)
# --> 306   return pjit.common_infer_params(pjit_info_args, *args, **kwargs)
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/pjit.py:505, in common_infer_params(***failed resolving arguments***)
#     499   in_type = in_avals = tuple(avals)
#     501 canonicalized_in_shardings_flat = _process_in_axis_resources(
#     502     hashable_pytree(in_shardings), in_avals, in_tree, resource_env, dbg,
#     503     device_or_backend_set)
# --> 505 jaxpr, consts, canonicalized_out_shardings_flat = _pjit_jaxpr(
#     506     flat_fun, hashable_pytree(out_shardings), in_type, dbg,
#     507     device_or_backend_set, HashableFunction(out_tree, closure=()),
#     508     HashableFunction(res_paths, closure=()))
#     510 assert len(explicit_args) == len(canonicalized_in_shardings_flat)
#     512 if config.jax_dynamic_shapes:
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/pjit.py:971, in _pjit_jaxpr(fun, out_shardings_thunk, in_type, debug_info, device_or_backend_set, out_tree, result_paths)
#     969 def _pjit_jaxpr(fun, out_shardings_thunk, in_type, debug_info,
#     970                 device_or_backend_set, out_tree, result_paths):
# --> 971   jaxpr, final_consts, out_type = _create_pjit_jaxpr(
#     972       fun, in_type, debug_info, result_paths)
#     973   canonicalized_out_shardings_flat = _check_and_canonicalize_out_shardings(
#     974       out_shardings_thunk, out_tree, tuple(out_type), jaxpr.jaxpr.debug_info,
#     975       device_or_backend_set)
#     976   # lu.cache needs to be able to create weakrefs to outputs, so we can't return a plain tuple
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/linear_util.py:345, in cache.<locals>.memoized_fun(fun, *args)
#     343   fun.populate_stores(stores)
#     344 else:
# --> 345   ans = call(fun, *args)
#     346   cache[key] = (ans, fun.stores)
#     348 return ans
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/pjit.py:924, in _create_pjit_jaxpr(fun, in_type, debug_info, out_paths)
#     921     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic2(
#     922         lu.annotate(fun, in_type), debug_info=pe_debug)
#     923   else:
# --> 924     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(
#     925         fun, in_type, debug_info=pe_debug)
#     927 if not config.jax_dynamic_shapes:
#     928   jaxpr = jaxpr_debug_info(jaxpr, debug_info, out_paths())
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/interpreters/partial_eval.py:2155, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2153 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2154   main.jaxpr_stack = ()  # type: ignore
# -> 2155   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2156     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2157   del main, fun
#    2158 return jaxpr, out_avals, consts
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/interpreters/partial_eval.py:2177, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2175 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2176 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2177 ans = fun.call_wrapped(*in_tracers_)
#    2178 out_tracers = map(trace.full_raise, ans)
#    2179 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/linear_util.py:188, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     185 gen = gen_static_args = out_store = None
#     187 try:
# --> 188   ans = self.f(*args, **dict(self.params, **kwargs))
#     189 except:
#     190   # Some transformations yield from inside context managers, so we have to
#     191   # interrupt them before reraising the exception. Otherwise they will only
#     192   # get garbage-collected at some later time, running their cleanup tasks
#     193   # only after this exception is handled, which can corrupt the global
#     194   # state.
#     195   while stack:
#
# Cell In[35], line 59, in simulate_ackerman(initial_state, disturbed_controls, data, uOpt_vel, uOpt_angle, coords, dt, L)
#      56     return new_state, new_state
#      58 # Use jax.lax.scan to iterate over the controls and accumulate the states
# ---> 59 _, states = jax.lax.scan(step, initial_state, disturbed_controls)
#      61 # Convert states to a JAX array
#      62 states = jnp.array(states)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/lax/control_flow/loops.py:250, in scan(f, init, xs, length, reverse, unroll)
#     243   return init_flat, carry_avals, carry_avals_out, init_tree, in_flat, jaxpr, consts, out_tree, out_tree_children
#     245 # The carry input and output avals must match exactly. However, we want to account for
#     246 # the case when init contains weakly-typed values (e.g. Python scalars), with avals that
#     247 # may not match the output despite being compatible by virtue of their weak type.
#     248 # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#     249 # necessary, a second time with modified init values.
# --> 250 init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#     251 new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#     252 if changed:
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/lax/control_flow/loops.py:236, in scan.<locals>._create_jaxpr(init)
#     233 in_flat, in_tree = tree_flatten((init, xs))
#     235 carry_avals = tuple(_map(_abstractify, init_flat))
# --> 236 jaxpr, consts, out_tree = _initial_style_jaxpr(
#     237     f, in_tree, (*carry_avals, *x_avals), "scan")
#     238 out_tree_children = out_tree.children()
#     239 if len(out_tree_children) != 2:
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/lax/control_flow/common.py:64, in _initial_style_jaxpr(fun, in_tree, in_avals, primitive_name)
#      61 @weakref_lru_cache
#      62 def _initial_style_jaxpr(fun: Callable, in_tree, in_avals,
#      63                          primitive_name: Optional[str] = None):
# ---> 64   jaxpr, consts, out_tree = _initial_style_open_jaxpr(
#      65       fun, in_tree, in_avals, primitive_name)
#      66   closed_jaxpr = core.ClosedJaxpr(pe.convert_constvars_jaxpr(jaxpr), ())
#      67   return closed_jaxpr, consts, out_tree
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/lax/control_flow/common.py:58, in _initial_style_open_jaxpr(fun, in_tree, in_avals, primitive_name)
#      55 wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
#      56 debug = pe.debug_info(fun, in_tree, out_tree, False,
#      57                       primitive_name or "<unknown>")
# ---> 58 jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals, debug)
#      59 return jaxpr, consts, out_tree()
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/interpreters/partial_eval.py:2155, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2153 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2154   main.jaxpr_stack = ()  # type: ignore
# -> 2155   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2156     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2157   del main, fun
#    2158 return jaxpr, out_avals, consts
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/interpreters/partial_eval.py:2177, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2175 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2176 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2177 ans = fun.call_wrapped(*in_tracers_)
#    2178 out_tracers = map(trace.full_raise, ans)
#    2179 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/jax/_src/linear_util.py:188, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     185 gen = gen_static_args = out_store = None
#     187 try:
# --> 188   ans = self.f(*args, **dict(self.params, **kwargs))
#     189 except:
#     190   # Some transformations yield from inside context managers, so we have to
#     191   # interrupt them before reraising the exception. Otherwise they will only
#     192   # get garbage-collected at some later time, running their cleanup tasks
#     193   # only after this exception is handled, which can corrupt the global
#     194   # state.
#     195   while stack:
#
# Cell In[35], line 54, in simulate_ackerman.<locals>.step(state, control)
#      51 uOpt= get_opt_control(x_deriv_now, y_deriv_now, th_deriv_now, state_now, V_MAX, V_MIN, DELTA_MAX)
#      53 # Update control with optimal values
# ---> 54 control = uOpt*(value_now<0.1) + control*(value_now>=0.1)
#      55 new_state = ackerman_dynamics(state, control.squeeze(), dt, L)
#      56 return new_state, new_state
#
# Cell In[35], line 54, in simulate_ackerman.<locals>.step(state, control)
#      51 uOpt= get_opt_control(x_deriv_now, y_deriv_now, th_deriv_now, state_now, V_MAX, V_MIN, DELTA_MAX)
#      53 # Update control with optimal values
# ---> 54 control = uOpt*(value_now<0.1) + control*(value_now>=0.1)
#      55 new_state = ackerman_dynamics(state, control.squeeze(), dt, L)
#      56 return new_state, new_state
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1152, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1135, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/debugpy/_vendored/pydevd/pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File ~/miniconda3/envs/hj/lib/python3.8/site-packages/debugpy/_vendored/pydevd/pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
from ipywidgets import interact

# Assuming state_history , matlab_var_dict, data_lx, data, m_t, and list_hallucinations_at_idx are defined elsewhere in your code
state_history = np.array(state_history)
control_history = np.array(control_history)

def plot_func(idx_to_plot):
    state_plot = state_history [idx_to_plot]
    # Print the state with 2 decimals
    print('[x,y,th]')
    print(np.around(state_plot, decimals=2))
    # Get the index of the closest v and th to the state_first_fltr
    th_idx = np.argmin(np.abs(matlab_var_dict['th_coord'] - state_plot[2]))

    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(6, 18))

    ####race track#####
    data1 = data_lx
    data1 = data1.transpose()
    CP1 = ax1.contour(matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], data1, 0, colors='red', linewidths=1)

    data2 = data[:, :, th_idx]  # Slice of lx
    data2 = data2.transpose()
    CP2 = ax1.contour(matlab_var_dict['x_coord'], matlab_var_dict['y_coord'], data2, 0, colors='blue', linewidths=1)

    # Grab closest theta
    th = matlab_var_dict['th_coord']
    th = th[th_idx]
    # Plot trajectory and final state
    SP1 = ax1.scatter(state_history [0:idx_to_plot, 0], state_history[0:idx_to_plot, 1], c=m_t[0:idx_to_plot], s=5, alpha=0.5) #
    SP2 = ax1.scatter(state_history [idx_to_plot, 0], state_history [idx_to_plot, 1], s=10, c=[[0.0, 0.0, 0.0]], alpha=1.0)
    # Plot arrow at final state
    
    #ax1.arrow(state_history [idx_to_plot, 0], state_history [idx_to_plot, 1], np.cos(th) * 0.2, np.sin(th) * 0.2, head_width=0.1, head_length=0.1, fc='k', ec='k')

    # Plot the hallucinations corresponding to idx_to_plot        
    for i in range(0, len(hallucination_history[idx_to_plot]), 20):
        h = hallucination_history[idx_to_plot][i]
        ax1.plot(h[0, :], h[1, :], color='green', alpha=0.2)

    # Set x and y limits
    ax1.set_xlim([0, 6])
    ax1.set_ylim([0, 4])

    # Change aspect ratio to match the grid
    ax1.set_aspect('equal')

    ####velocity plot####
    ax2.plot(control_history[:idx_to_plot+1, 0])
    ax2.scatter(idx_to_plot, control_history[idx_to_plot, 0], s=10, c=[[0.0, 0.0, 0.0]], alpha=1.0)
    ax2.set_title('velocity control')
    ax2.set_xlabel('k')
    ax2.set_aspect(aspect=50)

    ####angle plot####
    ax3.plot(control_history[:idx_to_plot+1, 1])
    ax3.scatter(idx_to_plot, control_history[idx_to_plot, 1], s=10, c=[[0.0, 0.0, 0.0]], alpha=1.0)
    ax3.set_title('angle control')
    ax3.set_xlabel('k')
    ax3.set_aspect(aspect=50)
       
    
    plt.show()

# Use interact to create a slider for idx_to_plot
interact(plot_func, idx_to_plot=(0, len(state_history ) - 2, 1))
# Out:
# interactive(children=(IntSlider(value=299, description='idx_to_plot', max=598), Output()), _dom_classes=('widg…
# <function __main__.plot_func(idx_to_plot)>

# %%
for i, elem in enumerate(control_history):
    print(f"Element {i} shape: {np.shape(elem)}")
# Out:
# Element 0 shape: (2,)
# Element 1 shape: (2,)
# Element 2 shape: (2,)
# Element 3 shape: (2,)
# Element 4 shape: (2,)
# Element 5 shape: (2,)
# Element 6 shape: (2,)
# Element 7 shape: (2,)
# Element 8 shape: (2,)
# Element 9 shape: (2,)
# Element 10 shape: (2,)
# Element 11 shape: (2,)
# Element 12 shape: (2,)
# Element 13 shape: (2,)
# Element 14 shape: (2,)
# Element 15 shape: (2,)
# Element 16 shape: (2,)
# Element 17 shape: (2,)
# Element 18 shape: (2,)
# Element 19 shape: (2,)
# Element 20 shape: (2,)
# Element 21 shape: (2,)
# Element 22 shape: (2,)
# Element 23 shape: (2,)
# Element 24 shape: (2,)
# Element 25 shape: (2,)
# Element 26 shape: (2,)
# Element 27 shape: (2,)
# Element 28 shape: (2,)
# Element 29 shape: (2,)
# Element 30 shape: (2,)
# Element 31 shape: (2,)
# Element 32 shape: (2,)
# Element 33 shape: (2,)
# Element 34 shape: (2,)
# Element 35 shape: (2,)
# Element 36 shape: (2,)
# Element 37 shape: (2,)
# Element 38 shape: (2,)
# Element 39 shape: (2,)
# Element 40 shape: (2,)
# Element 41 shape: (2,)
# Element 42 shape: (2,)
# Element 43 shape: (2,)
# Element 44 shape: (2,)
# Element 45 shape: (2,)
# Element 46 shape: (2,)
# Element 47 shape: (2,)
# Element 48 shape: (2,)
# Element 49 shape: (2,)
# Element 50 shape: (2,)
# Element 51 shape: (2,)
# Element 52 shape: (2,)
# Element 53 shape: (2,)
# Element 54 shape: (2,)
# Element 55 shape: (2,)
# Element 56 shape: (2,)
# Element 57 shape: (2,)
# Element 58 shape: (2,)
# Element 59 shape: (2,)
# Element 60 shape: (2,)
# Element 61 shape: (2,)
# Element 62 shape: (2,)
# Element 63 shape: (2,)
# Element 64 shape: (2,)
# Element 65 shape: (2,)
# Element 66 shape: (2,)
# Element 67 shape: (2,)
# Element 68 shape: (2,)
# Element 69 shape: (2,)
# Element 70 shape: (2,)
# Element 71 shape: (2,)
# Element 72 shape: (2,)
# Element 73 shape: (2,)
# Element 74 shape: (2,)
# Element 75 shape: (2,)
# Element 76 shape: (2,)
# Element 77 shape: (2,)
# Element 78 shape: (2,)
# Element 79 shape: (2,)
# Element 80 shape: (2,)
# Element 81 shape: (2,)
# Element 82 shape: (2,)
# Element 83 shape: (2,)
# Element 84 shape: (2, 1)
# Element 85 shape: (2, 1)
# Element 86 shape: (2, 1)
# Element 87 shape: (2, 1)
# Element 88 shape: (2, 1)
# Element 89 shape: (2, 1)
# Element 90 shape: (2, 1)
# Element 91 shape: (2, 1)
# Element 92 shape: (2, 1)
# Element 93 shape: (2, 1)
# Element 94 shape: (2, 1)
# Element 95 shape: (2, 1)
# Element 96 shape: (2,)
# Element 97 shape: (2,)
# Element 98 shape: (2,)
# Element 99 shape: (2,)
# Element 100 shape: (2,)
# Element 101 shape: (2,)
# Element 102 shape: (2,)
# Element 103 shape: (2,)
# Element 104 shape: (2,)
# Element 105 shape: (2,)
# Element 106 shape: (2, 1)
# Element 107 shape: (2,)
# Element 108 shape: (2, 1)
# Element 109 shape: (2, 1)
# Element 110 shape: (2, 1)
# Element 111 shape: (2, 1)
# Element 112 shape: (2, 1)
# Element 113 shape: (2, 1)
# Element 114 shape: (2, 1)
# Element 115 shape: (2, 1)
# Element 116 shape: (2, 1)
# Element 117 shape: (2, 1)
# Element 118 shape: (2, 1)
# Element 119 shape: (2,)
# Element 120 shape: (2,)
# Element 121 shape: (2,)
# Element 122 shape: (2,)
# Element 123 shape: (2,)
# Element 124 shape: (2,)
# Element 125 shape: (2,)
# Element 126 shape: (2,)
# Element 127 shape: (2,)
# Element 128 shape: (2,)
# Element 129 shape: (2,)
# Element 130 shape: (2,)
# Element 131 shape: (2,)
# Element 132 shape: (2,)
# Element 133 shape: (2,)
# Element 134 shape: (2,)
# Element 135 shape: (2,)
# Element 136 shape: (2,)
# Element 137 shape: (2,)
# Element 138 shape: (2,)
# Element 139 shape: (2,)
# Element 140 shape: (2,)
# Element 141 shape: (2,)
# Element 142 shape: (2,)
# Element 143 shape: (2,)
# Element 144 shape: (2,)
# Element 145 shape: (2,)
# Element 146 shape: (2,)
# Element 147 shape: (2,)
# Element 148 shape: (2,)
# Element 149 shape: (2,)
# Element 150 shape: (2,)
# Element 151 shape: (2,)
# Element 152 shape: (2,)
# Element 153 shape: (2,)
# Element 154 shape: (2,)
# Element 155 shape: (2,)
# Element 156 shape: (2,)
# Element 157 shape: (2,)
# Element 158 shape: (2,)
# Element 159 shape: (2,)
# Element 160 shape: (2,)
# Element 161 shape: (2,)
# Element 162 shape: (2,)
# Element 163 shape: (2,)
# Element 164 shape: (2,)
# Element 165 shape: (2,)
# Element 166 shape: (2,)
# Element 167 shape: (2,)
# Element 168 shape: (2,)
# Element 169 shape: (2,)
# Element 170 shape: (2,)
# Element 171 shape: (2, 1)
# Element 172 shape: (2, 1)
# Element 173 shape: (2, 1)
# Element 174 shape: (2,)
# Element 175 shape: (2,)
# Element 176 shape: (2,)
# Element 177 shape: (2,)
# Element 178 shape: (2,)
# Element 179 shape: (2,)
# Element 180 shape: (2,)
# Element 181 shape: (2,)
# Element 182 shape: (2,)
# Element 183 shape: (2,)
# Element 184 shape: (2,)
# Element 185 shape: (2,)
# Element 186 shape: (2,)
# Element 187 shape: (2,)
# Element 188 shape: (2,)
# Element 189 shape: (2,)
# Element 190 shape: (2,)
# Element 191 shape: (2,)
# Element 192 shape: (2,)
# Element 193 shape: (2,)
# Element 194 shape: (2, 1)
# Element 195 shape: (2, 1)
# Element 196 shape: (2, 1)
# Element 197 shape: (2,)
# Element 198 shape: (2, 1)
# Element 199 shape: (2, 1)
# Element 200 shape: (2, 1)
# Element 201 shape: (2, 1)
# Element 202 shape: (2, 1)
# Element 203 shape: (2, 1)
# Element 204 shape: (2, 1)
# Element 205 shape: (2, 1)
# Element 206 shape: (2, 1)
# Element 207 shape: (2, 1)
# Element 208 shape: (2, 1)
# Element 209 shape: (2,)
# Element 210 shape: (2,)
# Element 211 shape: (2, 1)
# Element 212 shape: (2, 1)
# Element 213 shape: (2, 1)
# Element 214 shape: (2, 1)
# Element 215 shape: (2, 1)
# Element 216 shape: (2,)
# Element 217 shape: (2,)
# Element 218 shape: (2,)
# Element 219 shape: (2,)
# Element 220 shape: (2,)
# Element 221 shape: (2,)
# Element 222 shape: (2,)
# Element 223 shape: (2,)
# Element 224 shape: (2, 1)
# Element 225 shape: (2, 1)
# Element 226 shape: (2, 1)
# Element 227 shape: (2, 1)
# Element 228 shape: (2, 1)
# Element 229 shape: (2, 1)
# Element 230 shape: (2, 1)
# Element 231 shape: (2,)
# Element 232 shape: (2,)
# Element 233 shape: (2,)
# Element 234 shape: (2,)
# Element 235 shape: (2,)
# Element 236 shape: (2,)
# Element 237 shape: (2,)
# Element 238 shape: (2,)
# Element 239 shape: (2,)
# Element 240 shape: (2,)
# Element 241 shape: (2,)
# Element 242 shape: (2,)
# Element 243 shape: (2,)
# Element 244 shape: (2,)
# Element 245 shape: (2,)
# Element 246 shape: (2,)
# Element 247 shape: (2, 1)
# Element 248 shape: (2, 1)
# Element 249 shape: (2, 1)
# Element 250 shape: (2, 1)
# Element 251 shape: (2, 1)
# Element 252 shape: (2, 1)
# Element 253 shape: (2, 1)
# Element 254 shape: (2, 1)
# Element 255 shape: (2,)
# Element 256 shape: (2,)
# Element 257 shape: (2,)
# Element 258 shape: (2,)
# Element 259 shape: (2,)
# Element 260 shape: (2,)
# Element 261 shape: (2,)
# Element 262 shape: (2,)
# Element 263 shape: (2,)
# Element 264 shape: (2,)
# Element 265 shape: (2,)
# Element 266 shape: (2,)
# Element 267 shape: (2,)
# Element 268 shape: (2,)
# Element 269 shape: (2,)
# Element 270 shape: (2,)
# Element 271 shape: (2,)
# Element 272 shape: (2,)
# Element 273 shape: (2,)
# Element 274 shape: (2, 1)
# Element 275 shape: (2, 1)
# Element 276 shape: (2, 1)
# Element 277 shape: (2, 1)
# Element 278 shape: (2, 1)
# Element 279 shape: (2, 1)
# Element 280 shape: (2, 1)
# Element 281 shape: (2, 1)
# Element 282 shape: (2,)
# Element 283 shape: (2, 1)
# Element 284 shape: (2, 1)
# Element 285 shape: (2, 1)
# Element 286 shape: (2, 1)
# Element 287 shape: (2,)
# Element 288 shape: (2,)
# Element 289 shape: (2,)
# Element 290 shape: (2,)
# Element 291 shape: (2,)
# Element 292 shape: (2,)
# Element 293 shape: (2,)
# Element 294 shape: (2,)
# Element 295 shape: (2,)
# Element 296 shape: (2,)
# Element 297 shape: (2,)
# Element 298 shape: (2,)
# Element 299 shape: (2,)
# Element 300 shape: (2,)
# Element 301 shape: (2,)
# Element 302 shape: (2,)
# Element 303 shape: (2,)
# Element 304 shape: (2,)
# Element 305 shape: (2,)
# Element 306 shape: (2,)
# Element 307 shape: (2, 1)
# Element 308 shape: (2, 1)
# Element 309 shape: (2,)
# Element 310 shape: (2, 1)
# Element 311 shape: (2, 1)
# Element 312 shape: (2, 1)
# Element 313 shape: (2, 1)
# Element 314 shape: (2, 1)
# Element 315 shape: (2, 1)
# Element 316 shape: (2, 1)
# Element 317 shape: (2, 1)
# Element 318 shape: (2,)
# Element 319 shape: (2, 1)
# Element 320 shape: (2, 1)
# Element 321 shape: (2, 1)
# Element 322 shape: (2, 1)
# Element 323 shape: (2, 1)
# Element 324 shape: (2, 1)
# Element 325 shape: (2, 1)
# Element 326 shape: (2, 1)
# Element 327 shape: (2, 1)
# Element 328 shape: (2, 1)
# Element 329 shape: (2,)
# Element 330 shape: (2,)
# Element 331 shape: (2,)
# Element 332 shape: (2,)
# Element 333 shape: (2,)
# Element 334 shape: (2,)
# Element 335 shape: (2,)
# Element 336 shape: (2,)
# Element 337 shape: (2,)
# Element 338 shape: (2,)
# Element 339 shape: (2,)
# Element 340 shape: (2,)
# Element 341 shape: (2,)
# Element 342 shape: (2,)
# Element 343 shape: (2,)
# Element 344 shape: (2, 1)
# Element 345 shape: (2, 1)
# Element 346 shape: (2, 1)
# Element 347 shape: (2, 1)
# Element 348 shape: (2, 1)
# Element 349 shape: (2, 1)
# Element 350 shape: (2, 1)
# Element 351 shape: (2, 1)
# Element 352 shape: (2, 1)
# Element 353 shape: (2, 1)
# Element 354 shape: (2, 1)
# Element 355 shape: (2, 1)
# Element 356 shape: (2, 1)
# Element 357 shape: (2, 1)
# Element 358 shape: (2, 1)
# Element 359 shape: (2,)
# Element 360 shape: (2, 1)
# Element 361 shape: (2, 1)
# Element 362 shape: (2,)
# Element 363 shape: (2, 1)
# Element 364 shape: (2, 1)
# Element 365 shape: (2,)
# Element 366 shape: (2, 1)
# Element 367 shape: (2, 1)
# Element 368 shape: (2, 1)
# Element 369 shape: (2, 1)
# Element 370 shape: (2,)
# Element 371 shape: (2, 1)
# Element 372 shape: (2, 1)
# Element 373 shape: (2,)
# Element 374 shape: (2,)
# Element 375 shape: (2,)
# Element 376 shape: (2,)
# Element 377 shape: (2,)
# Element 378 shape: (2,)
# Element 379 shape: (2, 1)
# Element 380 shape: (2, 1)
# Element 381 shape: (2, 1)
# Element 382 shape: (2,)
# Element 383 shape: (2, 1)
# Element 384 shape: (2, 1)
# Element 385 shape: (2, 1)
# Element 386 shape: (2, 1)
# Element 387 shape: (2,)
# Element 388 shape: (2, 1)
# Element 389 shape: (2, 1)
# Element 390 shape: (2, 1)
# Element 391 shape: (2, 1)
# Element 392 shape: (2, 1)
# Element 393 shape: (2, 1)
# Element 394 shape: (2, 1)
# Element 395 shape: (2, 1)
# Element 396 shape: (2,)
# Element 397 shape: (2, 1)
# Element 398 shape: (2, 1)
# Element 399 shape: (2, 1)
# Element 400 shape: (2, 1)
# Element 401 shape: (2, 1)
# Element 402 shape: (2, 1)
# Element 403 shape: (2, 1)
# Element 404 shape: (2, 1)
# Element 405 shape: (2, 1)
# Element 406 shape: (2, 1)
# Element 407 shape: (2, 1)
# Element 408 shape: (2, 1)
# Element 409 shape: (2, 1)
# Element 410 shape: (2, 1)
# Element 411 shape: (2, 1)
# Element 412 shape: (2, 1)
# Element 413 shape: (2, 1)
# Element 414 shape: (2, 1)
# Element 415 shape: (2, 1)
# Element 416 shape: (2, 1)
# Element 417 shape: (2,)
# Element 418 shape: (2,)
# Element 419 shape: (2, 1)
# Element 420 shape: (2, 1)
# Element 421 shape: (2,)
# Element 422 shape: (2,)
# Element 423 shape: (2,)
# Element 424 shape: (2,)
# Element 425 shape: (2,)
# Element 426 shape: (2,)
# Element 427 shape: (2,)
# Element 428 shape: (2,)
# Element 429 shape: (2,)
# Element 430 shape: (2,)
# Element 431 shape: (2,)
# Element 432 shape: (2,)
# Element 433 shape: (2,)
# Element 434 shape: (2,)
# Element 435 shape: (2,)
# Element 436 shape: (2,)
# Element 437 shape: (2,)
# Element 438 shape: (2,)
# Element 439 shape: (2,)
# Element 440 shape: (2,)
# Element 441 shape: (2,)
# Element 442 shape: (2,)
# Element 443 shape: (2,)
# Element 444 shape: (2,)
# Element 445 shape: (2,)
# Element 446 shape: (2,)
# Element 447 shape: (2,)
# Element 448 shape: (2,)
# Element 449 shape: (2,)
# Element 450 shape: (2,)
# Element 451 shape: (2,)
# Element 452 shape: (2, 1)
# Element 453 shape: (2,)
# Element 454 shape: (2, 1)
# Element 455 shape: (2, 1)
# Element 456 shape: (2, 1)
# Element 457 shape: (2, 1)
# Element 458 shape: (2,)
# Element 459 shape: (2, 1)
# Element 460 shape: (2, 1)
# Element 461 shape: (2, 1)
# Element 462 shape: (2, 1)
# Element 463 shape: (2, 1)
# Element 464 shape: (2,)
# Element 465 shape: (2, 1)
# Element 466 shape: (2, 1)
# Element 467 shape: (2, 1)
# Element 468 shape: (2, 1)
# Element 469 shape: (2, 1)
# Element 470 shape: (2, 1)
# Element 471 shape: (2, 1)
# Element 472 shape: (2,)
# Element 473 shape: (2, 1)
# Element 474 shape: (2, 1)
# Element 475 shape: (2, 1)
# Element 476 shape: (2, 1)
# Element 477 shape: (2, 1)
# Element 478 shape: (2, 1)
# Element 479 shape: (2, 1)
# Element 480 shape: (2, 1)
# Element 481 shape: (2, 1)
# Element 482 shape: (2, 1)
# Element 483 shape: (2, 1)
# Element 484 shape: (2, 1)
# Element 485 shape: (2,)
# Element 486 shape: (2,)
# Element 487 shape: (2,)
# Element 488 shape: (2,)
# Element 489 shape: (2, 1)
# Element 490 shape: (2, 1)
# Element 491 shape: (2, 1)
# Element 492 shape: (2,)
# Element 493 shape: (2, 1)
# Element 494 shape: (2, 1)
# Element 495 shape: (2, 1)
# Element 496 shape: (2, 1)
# Element 497 shape: (2, 1)
# Element 498 shape: (2, 1)
# Element 499 shape: (2,)
# Element 500 shape: (2, 1)
# Element 501 shape: (2, 1)
# Element 502 shape: (2, 1)
# Element 503 shape: (2, 1)
# Element 504 shape: (2, 1)
# Element 505 shape: (2, 1)
# Element 506 shape: (2, 1)
# Element 507 shape: (2, 1)
# Element 508 shape: (2, 1)
# Element 509 shape: (2, 1)
# Element 510 shape: (2, 1)
# Element 511 shape: (2, 1)
# Element 512 shape: (2, 1)
# Element 513 shape: (2, 1)
# Element 514 shape: (2, 1)
# Element 515 shape: (2, 1)
# Element 516 shape: (2, 1)
# Element 517 shape: (2, 1)
# Element 518 shape: (2,)
# Element 519 shape: (2,)
# Element 520 shape: (2,)
# Element 521 shape: (2,)
# Element 522 shape: (2,)
# Element 523 shape: (2,)
# Element 524 shape: (2,)
# Element 525 shape: (2,)
# Element 526 shape: (2,)
# Element 527 shape: (2,)
# Element 528 shape: (2,)
# Element 529 shape: (2,)
# Element 530 shape: (2,)
# Element 531 shape: (2,)
# Element 532 shape: (2,)
# Element 533 shape: (2,)
# Element 534 shape: (2,)
# Element 535 shape: (2,)
# Element 536 shape: (2,)
# Element 537 shape: (2,)
# Element 538 shape: (2,)
# Element 539 shape: (2,)
# Element 540 shape: (2,)
# Element 541 shape: (2,)
# Element 542 shape: (2,)
# Element 543 shape: (2,)
# Element 544 shape: (2,)
# Element 545 shape: (2,)
# Element 546 shape: (2,)
# Element 547 shape: (2,)
# Element 548 shape: (2,)
# Element 549 shape: (2,)
# Element 550 shape: (2,)
# Element 551 shape: (2,)
# Element 552 shape: (2,)
# Element 553 shape: (2,)
# Element 554 shape: (2,)
# Element 555 shape: (2,)
# Element 556 shape: (2,)
# Element 557 shape: (2,)
# Element 558 shape: (2,)
# Element 559 shape: (2,)
# Element 560 shape: (2,)
# Element 561 shape: (2,)
# Element 562 shape: (2,)
# Element 563 shape: (2,)
# Element 564 shape: (2,)
# Element 565 shape: (2,)
# Element 566 shape: (2,)
# Element 567 shape: (2,)
# Element 568 shape: (2,)
# Element 569 shape: (2,)
# Element 570 shape: (2,)
# Element 571 shape: (2,)
# Element 572 shape: (2,)
# Element 573 shape: (2,)
# Element 574 shape: (2,)
# Element 575 shape: (2,)
# Element 576 shape: (2,)
# Element 577 shape: (2,)
# Element 578 shape: (2,)
# Element 579 shape: (2,)
# Element 580 shape: (2,)
# Element 581 shape: (2,)
# Element 582 shape: (2,)
# Element 583 shape: (2,)
# Element 584 shape: (2,)
# Element 585 shape: (2,)
# Element 586 shape: (2,)
# Element 587 shape: (2,)
# Element 588 shape: (2,)
# Element 589 shape: (2,)
# Element 590 shape: (2,)
# Element 591 shape: (2,)
# Element 592 shape: (2,)
# Element 593 shape: (2,)
# Element 594 shape: (2,)
# Element 595 shape: (2,)
# Element 596 shape: (2,)
# Element 597 shape: (2,)
# Element 598 shape: (2,)
# Element 599 shape: (2,)

# %%
# Visualize the state trajectories
hallucinations = hallucination_history[0]
plt.figure(figsize=(10, 6))
for i in range(NUM_THREADS):
    x_coords = jnp.array(hallucinations)[i, 0, :]
    y_coords = jnp.array(hallucinations)[i, 1, :]
    plt.plot(x_coords, y_coords, color='tab:blue', alpha=0.3)  
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.title('State Trajectories of Ackerman Steering System with External Noise')
plt.grid(True)
# Set x and y limits
plt.xlim([0, 6])
plt.ylim([0, 4])
plt.show()

# Print the total cost for each trajectory
print("Total costs for each trajectory:", costs_parallel)

# %%
# Ensure you are in a Jupyter Notebook environment
# Use %timeit to measure the execution time
# %timeit -n 20 -r 10 states_parallel = simulate_ackerman_parallel(initial_state, disturbed_controls); jax.block_until_ready(states_parallel)
